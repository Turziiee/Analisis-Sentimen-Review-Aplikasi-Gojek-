# %%
# %pip install matplotlib seaborn wordcloud
# Out:
# Requirement already satisfied: matplotlib in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (3.10.3)
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting wordcloud
#   Downloading wordcloud-1.9.6-cp313-cp313-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.3.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (3.0.2)
# Requirement already satisfied: tzdata in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading wordcloud-1.9.6-cp313-cp313-win_amd64.whl (306 kB)
# Installing collected packages: wordcloud, seaborn
#
#    ---------------------------------------- 0/2 [wordcloud]
#    -------------------- ------------------- 1/2 [seaborn]
#    -------------------- ------------------- 1/2 [seaborn]
#    -------------------- ------------------- 1/2 [seaborn]
#    -------------------- ------------------- 1/2 [seaborn]
#    -------------------- ------------------- 1/2 [seaborn]
#    -------------------- ------------------- 1/2 [seaborn]
#    -------------------- ------------------- 1/2 [seaborn]
#    ---------------------------------------- 2/2 [seaborn]
#
# Successfully installed seaborn-0.13.2 wordcloud-1.9.6
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script wordcloud_cli.exe is installed in 'c:\Users\VICTUS\AppData\Local\Programs\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %%
df = pd.read_csv('../data/processed/gojek_reviews_preprocessed.csv')
df.head()
# Out:
#                                reviewId       userName  \
# 0  1c637a3a-43d8-453a-8da5-48a2d26927bc        Sudarto
# 1  e851b0c8-862d-4dca-b2db-875e6c03a625     kamu nanya
# 2  1dab09ce-061f-4751-b58c-ef12b03753b8           FTHR
# 3  da593ef8-bc9f-42ce-8aac-3ab0bb5e768f  Safitri Yenii
# 4  3eb584fc-95bd-4c07-b9cb-b45850ea82a7   Hartono Jack
#
#                                              content  score  thumbsUpCount  \
# 0                                    sangat membantu      5              0
# 1  terlalu lama mendapatkan driver di daerah cipa...      1              0
# 2                          sampai saat ini masih oke      5              0
# 3                               sangat membantu saya      5              0
# 4     menyenangkan transaksi belanja mudah dan cepat      5              0
#
#                     at                                       replyContent  \
# 0  2025-10-28T00:53:58                                                NaN
# 1  2025-10-28T00:53:22  Mohon maaf ya, Kak @kamu nanya. Kesulitan mend...
# 2  2025-10-28T00:00:17                                                NaN
# 3  2025-10-28T00:00:06                                                NaN
# 4  2025-10-27T23:44:59                                                NaN
#
#              repliedAt version language     label  \
# 0                  NaN  5.31.2       id  positive
# 1  2025-10-28T07:01:18  5.35.1       id  negative
# 2                  NaN  5.36.2       id  positive
# 3                  NaN     NaN       id  positive
# 4                  NaN     NaN       id  positive
#
#                                    cleaned
# 0                                    bantu
# 1  driver daerah cipanas keburu mood makan
# 2                                      oke
# 3                                    bantu
# 4     senang transaksi belanja mudah cepat

# %%
df.info()
df['label'].value_counts()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 98558 entries, 0 to 98557
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   reviewId       98558 non-null  str
#  1   userName       98557 non-null  str
#  2   content        98558 non-null  str
#  3   score          98558 non-null  int64
#  4   thumbsUpCount  98558 non-null  int64
#  5   at             98558 non-null  str
#  6   replyContent   38019 non-null  str
#  7   repliedAt      38019 non-null  str
#  8   version        78181 non-null  str
#  9   language       98558 non-null  str
#  10  label          98558 non-null  str
#  11  cleaned        96594 non-null  str
# dtypes: int64(2), str(10)
# memory usage: 9.0 MB
# label
# positive    57666
# negative    36199
# neutral      4693
# Name: count, dtype: int64

# %%
sns.countplot(x='label', data=df)
plt.title('Distribution of Sentiment Labels')
plt.show()

# %%
df['text_length'] = df['cleaned'].apply(lambda x: len(str(x).split()))
sns.histplot(data=df, x='text_length', bins=30)
plt.title('Distribution of Text Lengths')
plt.show()

# %%
for label in df['label'].unique():
    text = ' '.join(df[df['label'] == label]['cleaned'].dropna().astype(str))
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title(f"WordCloud untuk Label: {label}")
    plt.show()
